# %% [raw]
# NOW WE START THE MOST IMPORTANT RETAIL AI PHASE
# RFM FEATURE ENGINEERING
#
# This is the FOUNDATION of:
#
# churn prediction,
# customer segmentation,
# recommendation systems,
# customer intelligence.
#
# WHAT IS RFM?
# Feature	Meaning
# R	Recency
# F	Frequency
# M	Monetary

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

customer_df = pd.read_csv(
    r"C:\Users\91991\Desktop\internships\AMDOX\data\processed\clean_online_retail.csv"
)

# %%
customer_df["InvoiceDate"] = pd.to_datetime(
    customer_df["InvoiceDate"]
)

# %%
customer_df["InvoiceDate"].max()
# Out:
# Timestamp('2010-12-09 20:01:00')

# %%
snapshot_date = customer_df[
    "InvoiceDate"
].max() + pd.Timedelta(days=1)

print(snapshot_date)
# Out:
# 2010-12-10 20:01:00

# %%
rfm_df = customer_df.groupby(
    "Customer ID"
).agg({

    "InvoiceDate": lambda x: (
        snapshot_date - x.max()
    ).days,

    "Invoice": "nunique",

    "Revenue": "sum"

}).reset_index()

# %%
rfm_df.columns = [
    "CustomerID",
    "Recency",
    "Frequency",
    "Monetary"
]

# %%
rfm_df.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0       12346      165         11    372.86
# 1       12347        3          2   1323.32
# 2       12348       74          1    222.16
# 3       12349       43          3   2671.14
# 4       12351       11          1    300.93

# %%
rfm_df.to_csv(
    r"C:\Users\91991\Desktop\internships\AMDOX\data\processed\rfm_features.csv",
    index=False
)
