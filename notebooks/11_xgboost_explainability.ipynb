# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import shap
import joblib

# %%
model = joblib.load(
    r"C:\Users\91991\Desktop\internships\AMDOX\models\forecasting\xgboost_forecast.pkl"
)

print(type(model))
# Out:
# <class 'xgboost.sklearn.XGBRegressor'>

# %%
df = pd.read_csv(
    r"C:\Users\91991\Desktop\internships\AMDOX\data\processed\daily_business_sales.csv"
)

print(df.shape)

df.head()
# Out:
# (1885, 22)
#       d  sales        date  wm_yr_wk    weekday  wday  month  year  \
# 0  d_29  29908  2011-02-26     11105   Saturday     1      2  2011
# 1  d_30  28707  2011-02-27     11105     Sunday     2      2  2011
# 2  d_31  21240  2011-02-28     11105     Monday     3      2  2011
# 3  d_32  22872  2011-03-01     11105    Tuesday     4      3  2011
# 4  d_33  22046  2011-03-02     11105  Wednesday     5      3  2011
#
#   event_name_1 event_type_1  ... snap_CA snap_TX  snap_WI    lag_7   lag_28  \
# 0          NaN          NaN  ...       0       0        0  31689.0  32631.0
# 1          NaN          NaN  ...       0       0        0  29283.0  31749.0
# 2          NaN          NaN  ...       0       0        0  23966.0  23783.0
# 3          NaN          NaN  ...       1       1        0  20501.0  25412.0
# 4          NaN          NaN  ...       1       0        1  20757.0  19146.0
#
#    rolling_mean_7  rolling_mean_28  day_of_week  week  is_event
# ...

# %%
features = [

    "lag_7",

    "lag_28",

    "rolling_mean_7",

    "rolling_mean_28",

    "day_of_week",

    "month",

    "week",

    "year",

    "is_event",

    "snap_CA",

    "snap_TX",

    "snap_WI"
]

target = "sales"

# %%
train_df = df.iloc[:-30]

test_df = df.iloc[-30:]

X_test = test_df[features]

y_test = test_df[target]

# %%
# explainer = shap.TreeExplainer(
#     model
# )

# shap_values = explainer.shap_values(
#     X_test
# )
explainer = shap.Explainer(
    model
)

shap_values = explainer(
    X_test
)
print(
    np.array(shap_values).shape
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 8
#       1 # explainer = shap.TreeExplainer(
#       2 #     model
#       3 # )
#    (...)
#       6 #     X_test
#       7 # )
# ----> 8 explainer = shap.Explainer(
#       9     model
#      10 )
#      12 shap_values = explainer(
#      13     X_test
#      14 )
#      15 print(
#      16     np.array(shap_values).shape
#      17 )
#
# File ~\anaconda3\envs\torch_env\lib\site-packages\shap\explainers\_explainer.py:204, in Explainer.__init__(self, model, masker, link, algorithm, output_names, feature_names, linearize_link, seed, **kwargs)
#     200             algorithm = "permutation"
#     202     # if we get here then we don't know how to handle what was given to us
#     203     else:
# --> 204         raise TypeError(
# ...

# %%
# explainer = shap.TreeExplainer(
#     model
# )

# shap_values = explainer.shap_values(
#     X_test
# )

print(
    np.array(shap_values).shape
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 9
#       1 # explainer = shap.TreeExplainer(
#       2 #     model
#       3 # )
#    (...)
#       6 #     X_test
#       7 # )
# ----> 9 explainer = shap.Explainer(
#      10     model
#      11 )
#      13 shap_values = explainer(
#      14     X_test
#      15 )
#      16 print(
#      17     np.array(shap_values).shape
#      18 )
#
# File ~\anaconda3\envs\torch_env\lib\site-packages\shap\explainers\_explainer.py:204, in Explainer.__init__(self, model, masker, link, algorithm, output_names, feature_names, linearize_link, seed, **kwargs)
#     200             algorithm = "permutation"
#     202     # if we get here then we don't know how to handle what was given to us
#     203     else:
# --> 204         raise TypeError(
# ...

# %%
explainer = shap.TreeExplainer(
    model
)

shap_values = explainer.shap_values(
    X_test
)

print(
    np.array(shap_values).shape
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 explainer = shap.TreeExplainer(
#       2     model
#       3 )
#       5 shap_values = explainer.shap_values(
#       6     X_test
#       7 )
#       9 print(
#      10     np.array(shap_values).shape
#      11 )
#
# File ~\anaconda3\envs\torch_env\lib\site-packages\shap\explainers\_tree.py:278, in TreeExplainer.__init__(self, model, data, model_output, feature_perturbation, feature_names, approximate, link, linearize_link)
#     276 self.feature_perturbation = feature_perturbation
#     277 self.expected_value = None
# --> 278 self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     279 self.model_output = model_output
#     280 # self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#     281
# ...

# %%
shap.summary_plot(

    shap_values,

    X_test
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 shap.summary_plot(
#       2
# ----> 3     shap_values,
#       4
#       5     X_test
#       6 )
#
# NameError: name 'shap_values' is not defined

# %%
importance_df = pd.DataFrame({

    "Feature": X_test.columns,

    "Importance": np.abs(
        shap_values
    ).mean(axis=0)
})

importance_df = (

    importance_df

    .sort_values(
        "Importance",
        ascending=False
    )
)

importance_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 6
#       1 importance_df = pd.DataFrame({
#       2
#       3     "Feature": X_test.columns,
#       4
#       5     "Importance": np.abs(
# ----> 6         shap_values
#       7     ).mean(axis=0)
#       8 })
#      10 importance_df = (
#      11
#      12     importance_df
#    (...)
#      17     )
#      18 )
#      20 importance_df
#
# NameError: name 'shap_values' is not defined

# %%
print()

print(
    importance_df.head(10)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 print()
#       3 print(
# ----> 4     importance_df.head(10)
#       5 )
#
# NameError: name 'importance_df' is not defined

# %%
importance_df.to_csv(

    r"C:\Users\91991\Desktop\internships\AMDOX\data\processed\shap_feature_importance.csv",

    index=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 importance_df.to_csv(
#       2
#       3     r"C:\Users\91991\Desktop\internships\AMDOX\data\processed\shap_feature_importance.csv",
#       4
#       5     index=False
#       6 )
#
# NameError: name 'importance_df' is not defined

# %%
shap.summary_plot(

    shap_values,

    X_test,

    plot_type="bar",

    show=False
)

plt.tight_layout()

plt.savefig(

    r"C:\Users\91991\Desktop\internships\AMDOX\data\processed\shap_importance.png",

    bbox_inches="tight"
)

plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 shap.summary_plot(
#       2
# ----> 3     shap_values,
#       4
#       5     X_test,
#       6
#       7     plot_type="bar",
#       8
#       9     show=False
#      10 )
#      12 plt.tight_layout()
#      14 plt.savefig(
#      15
#      16     r"C:\Users\91991\Desktop\internships\AMDOX\data\processed\shap_importance.png",
#      17
#      18     bbox_inches="tight"
#      19 )
#
# NameError: name 'shap_values' is not defined

# %%
shap.summary_plot(

    shap_values,

    X_test,

    show=False
)

plt.tight_layout()

plt.savefig(

    r"C:\Users\91991\Desktop\internships\AMDOX\data\processed\shap_summary.png",

    bbox_inches="tight"
)

plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 shap.summary_plot(
#       2
# ----> 3     shap_values,
#       4
#       5     X_test,
#       6
#       7     show=False
#       8 )
#      10 plt.tight_layout()
#      12 plt.savefig(
#      13
#      14     r"C:\Users\91991\Desktop\internships\AMDOX\data\processed\shap_summary.png",
#      15
#      16     bbox_inches="tight"
#      17 )
#
# NameError: name 'shap_values' is not defined

# %%
import shap
import xgboost

print("SHAP:", shap.__version__)
print("XGBoost:", xgboost.__version__)
# Out:
# SHAP: 0.49.1
# XGBoost: 3.2.0
